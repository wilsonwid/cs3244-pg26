# %%
import csv
import math
import random
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error, r2_score, make_scorer, mean_absolute_error, mean_absolute_percentage_error, median_absolute_error
from sklearn.ensemble import AdaBoostRegressor
import pickle
from copy import deepcopy

# %%
def process_df(df):
  new_df = deepcopy(df)
  new_df["period_index"] = pd.PeriodIndex(df.sale_date, freq="Q")
  new_df.drop(columns=["id", "sale_date", "address", "latitude_rad", "longitude_rad", "latitude", "longitude", "psm"], inplace=True)
  new_df = pd.get_dummies(new_df, columns=["flat_type", "flat_model", "town"], dummy_na = True, dtype=np.uint8)
  new_df.drop(columns=["town_nan", "flat_type_nan", "flat_model_nan"], inplace=True)
  return new_df

# %%
def train_test_split(df, period):
  train = df[df["period_index"] != period]
  test = df[df["period_index"] == period]
  
  X_train, y_train = train[train.columns.difference(["cpi_psm", "period_index"])], train["cpi_psm"]
  X_test, y_test = test[test.columns.difference(["cpi_psm", "period_index"])], test["cpi_psm"]
  return X_train, X_test, y_train, y_test

# %%
PROCESSED_DATA_PATH = os.path.join("../", "../", "data_processed", "resale_flat_prices")
SEED = 42

# %%
df = pd.read_csv(os.path.join(PROCESSED_DATA_PATH, "engineered_data.csv"))
df.head(10)
# Out:
#    id         town flat_type flat_model   sale_date  floor  age  \
# 0   1  JURONG_WEST    3_ROOM   IMPROVED  1990-01-01    5.0   16
# 1   2        OTHER    5_ROOM   STANDARD  1990-01-01    5.0   15
# 2   3  BUKIT_MERAH    3_ROOM   IMPROVED  1990-01-01    5.0   15
# 3   4  BUKIT_MERAH     OTHER   IMPROVED  1990-01-01    8.0   21
# 4   5  BUKIT_MERAH     OTHER   IMPROVED  1990-01-01   11.0   21
# 5   6  BUKIT_MERAH     OTHER   IMPROVED  1990-01-01    8.0   21
# 6   7  BUKIT_MERAH    3_ROOM   IMPROVED  1990-01-01    8.0    7
# 7   8  BUKIT_MERAH    3_ROOM    MODEL_A  1990-01-01    8.0    6
# 8   9  BUKIT_MERAH    3_ROOM    MODEL_A  1990-01-01    5.0    6
# 9  10  BUKIT_MERAH    3_ROOM   IMPROVED  1990-01-01    2.0   15
#
#    relative_tenure  floor_area          psm  ... nearest_post_offices  \
# 0         0.899953        70.0   334.285714  ...             0.798752
# 1         0.902280       120.0   916.666667  ...             3.042559
# 2         0.902280        63.0   722.222222  ...             1.148847
# 3         0.887322        29.0   251.724138  ...             1.294327
# 4         0.887322        29.0   251.724138  ...             1.294327
# 5         0.887322        29.0   310.344828  ...             1.294327
# 6         0.918820        64.0   687.500000  ...             1.018641
# 7         0.920652        74.0  1128.378378  ...             1.089870
# 8         0.920652        73.0  1150.684932  ...             1.657478
# 9         0.902280        76.0   671.052632  ...             0.690789
#
#    nearest_bus_stops  nearest_pharmacies  nearest_primary_schools  \
# 0           0.195397            0.761661                 0.541789
# 1           0.090376            1.133326                 0.159056
# 2           0.446105            0.850333                 0.943485
# 3           1.620819            0.431442                 0.691163
# 4           1.620819            0.431442                 0.691163
# 5           1.620819            0.431442                 0.691163
# 6           0.485058            0.986821                 0.800866
# 7           0.544915            0.567711                 0.490547
# 8           0.053197            0.982875                 0.340834
# 9           0.083148            0.637859                 0.507003
#
#    nearest_parks  nearest_trains  sale_month   cpi      cpi_psm  avg_sora
# 0       0.947906        0.904104           1  61.9   595.125779       NaN
# 1       0.330270        1.954674           1  61.9  1631.933226       NaN
# 2       0.737703        0.932695           1  61.9  1285.765572       NaN
# 3       0.311404        0.448964           1  61.9   448.142165       NaN
# 4       0.311404        0.448964           1  61.9   448.142165       NaN
# 5       0.311404        0.448964           1  61.9   552.504039       NaN
# 6       0.808590        0.940111           1  61.9  1223.949919       NaN
# 7       0.708861        0.799126           1  61.9  2008.841636       NaN
# 8       1.013329        0.940071           1  61.9  2048.553788       NaN
# 9       0.406147        1.175060           1  61.9  1194.668821       NaN
#
# [10 rows x 29 columns]

# %%
df["is_imputted_sora"] = np.where(df["avg_sora"].isnull(), True, False)

imp = SimpleImputer()
df["avg_sora"] = imp.fit_transform(df["avg_sora"].to_numpy().reshape(-1, 1))

# %%
df.describe()
# Out:
#                   id          floor            age  relative_tenure  \
# count  865827.000000  865827.000000  865827.000000    865827.000000
# mean   432914.000000       7.626058      17.349350         0.892896
# std    249942.870098       4.738340      10.217708         0.029046
# min         1.000000       2.000000       0.000000         0.731586
# 25%    216457.500000       5.000000       9.000000         0.878870
# 50%    432914.000000       8.000000      16.000000         0.899953
# 75%    649370.500000      11.000000      24.000000         0.915007
# max    865827.000000      50.000000      55.000000         0.930702
#
#           floor_area            psm       latitude      longitude  \
# count  865827.000000  865827.000000  865827.000000  865827.000000
# mean       96.135123    3173.083607       1.497366     103.148474
# std        25.796313    1385.776553       2.612377      11.573640
# min        28.000000     161.290323     -37.840251    -122.683299
# 25%        73.000000    2266.666667       1.335322     103.772049
# 50%        93.000000    2870.370370       1.355961     103.843296
# 75%       114.000000    3990.180006       1.383056     103.897860
# max       307.000000   13310.344828      50.820779     145.019498
#
#         latitude_rad  longitude_rad  ...  nearest_post_offices  \
# count  865827.000000  865827.000000  ...         865827.000000
# mean        0.026134       1.800280  ...             62.788172
# std         0.045595       0.201998  ...            923.588875
# min        -0.660437      -2.141228  ...              0.007724
# 25%         0.023306       1.811164  ...              0.754831
# 50%         0.023666       1.812407  ...              1.136412
# 75%         0.024139       1.813360  ...              1.559133
# max         0.886990       2.531068  ...          16929.865540
#
#        nearest_bus_stops  nearest_pharmacies  nearest_primary_schools  \
# count      865827.000000       865827.000000            865827.000000
# mean           61.708270           62.231490                61.990540
# std           923.284911          923.497181               923.502716
# min             0.000003            0.000790                 0.042886
# 25%             0.076599            0.395358                 0.241143
# 50%             0.112533            0.610644                 0.370503
# 75%             0.156376            0.869802                 0.540301
# max         16924.138572        16928.066230             16927.190593
#
#        nearest_parks  nearest_trains     sale_month            cpi  \
# count  865827.000000   865827.000000  865827.000000  865827.000000
# mean       62.338973       62.217020     190.483063      82.131055
# std       923.385468      923.496916     104.298678      11.879488
# min         0.021691        0.018401       1.000000      61.900000
# 25%         0.477918        0.375599     107.000000      73.400000
# 50%         0.705703        0.585058     175.000000      76.500000
# 75%         0.994037        0.853369     269.000000      95.900000
# max     16926.344996    16927.966733     393.000000     110.200000
#
#              cpi_psm       avg_sora
# count  865827.000000  865827.000000
# mean     4131.625468       0.763427
# std      1363.166128       0.659903
# min       284.387097       0.035633
# 25%      3321.083800       0.260618
# 50%      4031.953168       0.763427
# 75%      4868.754343       0.763427
# max     14163.126574       3.414986
#
# [8 rows x 24 columns]

# %%
new_df = process_df(df)
sample_values = new_df.sample(frac=0.1, random_state=SEED)
X_train_sample, X_test_sample, y_train_sample, y_test_sample = train_test_split(sample_values, pd.Period(value="2022Q3"))

# %%
model = AdaBoostRegressor(base_estimator=DecisionTreeRegressor(random_state=SEED), random_state=SEED)

# %% [markdown]
# # GridSearchCV

# %%
parameters = {'n_estimators':[100,200,300,400,500],'learning_rate':[0.01,0.1,0.5,1.0]}
grid = GridSearchCV(model, parameters, scoring='neg_root_mean_squared_error', verbose = 4, return_train_score = True)
grid.fit(X=X_train_sample, y=y_train_sample)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END learning_rate=0.01, n_estimators=100;, score=(train=-10.991, test=-333.942) total time= 3.1min
# [CV 2/5] END learning_rate=0.01, n_estimators=100;, score=(train=-11.372, test=-333.538) total time= 3.0min
# [CV 3/5] END learning_rate=0.01, n_estimators=100;, score=(train=-10.236, test=-344.080) total time= 2.8min
# [CV 4/5] END learning_rate=0.01, n_estimators=100;, score=(train=-11.472, test=-336.868) total time= 2.9min
# [CV 5/5] END learning_rate=0.01, n_estimators=100;, score=(train=-11.263, test=-335.336) total time= 3.0min
# [CV 1/5] END learning_rate=0.01, n_estimators=200;, score=(train=-10.750, test=-330.409) total time= 5.7min
# [CV 2/5] END learning_rate=0.01, n_estimators=200;, score=(train=-11.357, test=-330.753) total time= 5.7min
# [CV 3/5] END learning_rate=0.01, n_estimators=200;, score=(train=-10.105, test=-341.028) total time= 5.6min
# [CV 4/5] END learning_rate=0.01, n_estimators=200;, score=(train=-11.346, test=-333.179) total time= 5.5min
# [CV 5/5] END learning_rate=0.01, n_estimators=200;, score=(train=-11.187, test=-331.661) total time= 5.5min
# [CV 1/5] END learning_rate=0.01, n_estimators=300;, score=(train=-10.743, test=-329.078) total time= 8.1min
# [CV 2/5] END learning_rate=0.01, n_estimators=300;, score=(train=-11.331, test=-329.484) total time= 8.1min
# [CV 3/5] END learning_rate=0.01, n_estimators=300;, score=(train=-10.102, test=-339.192) total time= 8.3min
# [CV 4/5] END learning_rate=0.01, n_estimators=300;, score=(train=-11.345, test=-332.588) total time= 8.4min
# [CV 5/5] END learning_rate=0.01, n_estimators=300;, score=(train=-11.184, test=-329.675) total time= 8.9min
# [CV 1/5] END learning_rate=0.01, n_estimators=400;, score=(train=-10.740, test=-329.126) total time=12.2min
# [CV 2/5] END learning_rate=0.01, n_estimators=400;, score=(train=-11.330, test=-327.325) total time=11.6min
# [CV 3/5] END learning_rate=0.01, n_estimators=400;, score=(train=-10.100, test=-338.006) total time=11.5min
# [CV 4/5] END learning_rate=0.01, n_estimators=400;, score=(train=-11.345, test=-331.693) total time=11.6min
# [CV 5/5] END learning_rate=0.01, n_estimators=400;, score=(train=-11.185, test=-328.737) total time=11.7min
# [CV 1/5] END learning_rate=0.01, n_estimators=500;, score=(train=-10.739, test=-328.388) total time=15.3min
# [CV 2/5] END learning_rate=0.01, n_estimators=500;, score=(train=-11.330, test=-326.443) total time=15.0min
# [CV 3/5] END learning_rate=0.01, n_estimators=500;, score=(train=-10.099, test=-337.223) total time=14.5min
# [CV 4/5] END learning_rate=0.01, n_estimators=500;, score=(train=-11.345, test=-331.147) total time=14.8min
# [CV 5/5] END learning_rate=0.01, n_estimators=500;, score=(train=-11.184, test=-328.059) total time=15.0min
# [CV 1/5] END learning_rate=0.1, n_estimators=100;, score=(train=-10.800, test=-329.294) total time= 2.9min
# [CV 2/5] END learning_rate=0.1, n_estimators=100;, score=(train=-11.352, test=-327.616) total time= 2.8min
# [CV 3/5] END learning_rate=0.1, n_estimators=100;, score=(train=-10.155, test=-337.500) total time= 2.8min
# [CV 4/5] END learning_rate=0.1, n_estimators=100;, score=(train=-11.384, test=-331.981) total time= 2.8min
# [CV 5/5] END learning_rate=0.1, n_estimators=100;, score=(train=-11.236, test=-328.479) total time= 2.9min
# [CV 1/5] END learning_rate=0.1, n_estimators=200;, score=(train=-10.869, test=-324.669) total time= 9.6min
# [CV 2/5] END learning_rate=0.1, n_estimators=200;, score=(train=-11.438, test=-327.110) total time=10.1min
# [CV 3/5] END learning_rate=0.1, n_estimators=200;, score=(train=-10.270, test=-335.124) total time=11.1min
# [CV 4/5] END learning_rate=0.1, n_estimators=200;, score=(train=-11.477, test=-329.954) total time=12.5min
# [CV 5/5] END learning_rate=0.1, n_estimators=200;, score=(train=-11.330, test=-323.588) total time=13.3min
# [CV 1/5] END learning_rate=0.1, n_estimators=300;, score=(train=-11.221, test=-322.394) total time=16.0min
# [CV 2/5] END learning_rate=0.1, n_estimators=300;, score=(train=-11.720, test=-326.655) total time=11.7min
# [CV 3/5] END learning_rate=0.1, n_estimators=300;, score=(train=-10.497, test=-333.339) total time= 8.6min
# [CV 4/5] END learning_rate=0.1, n_estimators=300;, score=(train=-11.804, test=-329.339) total time= 7.5min
# [CV 5/5] END learning_rate=0.1, n_estimators=300;, score=(train=-11.695, test=-322.606) total time= 8.0min
# [CV 1/5] END learning_rate=0.1, n_estimators=400;, score=(train=-12.513, test=-320.327) total time=11.0min
# [CV 2/5] END learning_rate=0.1, n_estimators=400;, score=(train=-12.425, test=-324.187) total time=11.0min
# [CV 3/5] END learning_rate=0.1, n_estimators=400;, score=(train=-10.976, test=-331.521) total time=10.0min
# [CV 4/5] END learning_rate=0.1, n_estimators=400;, score=(train=-12.968, test=-327.270) total time= 9.6min
# [CV 5/5] END learning_rate=0.1, n_estimators=400;, score=(train=-12.877, test=-321.021) total time=10.5min
# [CV 1/5] END learning_rate=0.1, n_estimators=500;, score=(train=-15.219, test=-318.586) total time=10.8min
# [CV 2/5] END learning_rate=0.1, n_estimators=500;, score=(train=-13.966, test=-321.388) total time=11.9min
# [CV 3/5] END learning_rate=0.1, n_estimators=500;, score=(train=-11.952, test=-330.426) total time=13.0min
# [CV 4/5] END learning_rate=0.1, n_estimators=500;, score=(train=-15.725, test=-324.978) total time=10.8min
# [CV 5/5] END learning_rate=0.1, n_estimators=500;, score=(train=-15.900, test=-319.344) total time= 9.9min
# [CV 1/5] END learning_rate=0.5, n_estimators=100;, score=(train=-18.454, test=-321.817) total time= 2.1min
# [CV 2/5] END learning_rate=0.5, n_estimators=100;, score=(train=-16.818, test=-320.506) total time= 2.3min
# [CV 3/5] END learning_rate=0.5, n_estimators=100;, score=(train=-13.727, test=-332.772) total time= 2.6min
# [CV 4/5] END learning_rate=0.5, n_estimators=100;, score=(train=-19.026, test=-327.230) total time= 2.7min
# [CV 5/5] END learning_rate=0.5, n_estimators=100;, score=(train=-18.733, test=-321.886) total time= 2.7min
# [CV 1/5] END learning_rate=0.5, n_estimators=200;, score=(train=-46.218, test=-314.691) total time= 4.0min
# [CV 2/5] END learning_rate=0.5, n_estimators=200;, score=(train=-38.198, test=-315.911) total time= 4.9min
# [CV 3/5] END learning_rate=0.5, n_estimators=200;, score=(train=-28.677, test=-326.154) total time= 4.5min
# [CV 4/5] END learning_rate=0.5, n_estimators=200;, score=(train=-47.885, test=-320.731) total time= 4.0min
# [CV 5/5] END learning_rate=0.5, n_estimators=200;, score=(train=-46.862, test=-317.102) total time= 4.0min
# [CV 1/5] END learning_rate=0.5, n_estimators=300;, score=(train=-70.029, test=-311.538) total time= 4.3min
# [CV 2/5] END learning_rate=0.5, n_estimators=300;, score=(train=-57.761, test=-313.595) total time= 5.5min
# [CV 3/5] END learning_rate=0.5, n_estimators=300;, score=(train=-44.201, test=-323.459) total time= 4.4min
# [CV 4/5] END learning_rate=0.5, n_estimators=300;, score=(train=-72.264, test=-318.404) total time= 5.3min
# [CV 5/5] END learning_rate=0.5, n_estimators=300;, score=(train=-71.482, test=-314.100) total time= 5.2min
# [CV 1/5] END learning_rate=0.5, n_estimators=400;, score=(train=-87.995, test=-310.426) total time= 5.2min
# [CV 2/5] END learning_rate=0.5, n_estimators=400;, score=(train=-72.622, test=-312.963) total time= 6.8min
# [CV 3/5] END learning_rate=0.5, n_estimators=400;, score=(train=-56.673, test=-322.349) total time= 5.2min
# [CV 4/5] END learning_rate=0.5, n_estimators=400;, score=(train=-89.969, test=-317.172) total time= 4.5min
# [CV 5/5] END learning_rate=0.5, n_estimators=400;, score=(train=-89.281, test=-313.286) total time= 4.5min
# [CV 1/5] END learning_rate=0.5, n_estimators=500;, score=(train=-101.013, test=-310.198) total time= 5.3min
# [CV 2/5] END learning_rate=0.5, n_estimators=500;, score=(train=-83.490, test=-312.464) total time= 7.4min
# [CV 3/5] END learning_rate=0.5, n_estimators=500;, score=(train=-66.382, test=-321.741) total time= 6.1min
# [CV 4/5] END learning_rate=0.5, n_estimators=500;, score=(train=-102.801, test=-316.908) total time= 5.3min
# [CV 5/5] END learning_rate=0.5, n_estimators=500;, score=(train=-102.475, test=-312.980) total time= 5.6min
# [CV 1/5] END learning_rate=1.0, n_estimators=100;, score=(train=-54.025, test=-316.025) total time= 1.4min
# [CV 2/5] END learning_rate=1.0, n_estimators=100;, score=(train=-43.013, test=-319.476) total time= 1.8min
# [CV 3/5] END learning_rate=1.0, n_estimators=100;, score=(train=-33.598, test=-328.558) total time= 1.7min
# [CV 4/5] END learning_rate=1.0, n_estimators=100;, score=(train=-57.193, test=-323.544) total time= 1.4min
# [CV 5/5] END learning_rate=1.0, n_estimators=100;, score=(train=-51.665, test=-316.590) total time= 1.5min
# [CV 1/5] END learning_rate=1.0, n_estimators=200;, score=(train=-94.220, test=-311.551) total time= 2.3min
# [CV 2/5] END learning_rate=1.0, n_estimators=200;, score=(train=-76.566, test=-315.279) total time= 3.1min
# [CV 3/5] END learning_rate=1.0, n_estimators=200;, score=(train=-61.082, test=-323.848) total time= 2.7min
# [CV 4/5] END learning_rate=1.0, n_estimators=200;, score=(train=-97.945, test=-320.755) total time= 2.3min
# [CV 5/5] END learning_rate=1.0, n_estimators=200;, score=(train=-92.019, test=-314.619) total time= 2.3min
# [CV 1/5] END learning_rate=1.0, n_estimators=300;, score=(train=-115.746, test=-310.983) total time= 3.2min
# [CV 2/5] END learning_rate=1.0, n_estimators=300;, score=(train=-94.587, test=-314.412) total time= 4.6min
# [CV 3/5] END learning_rate=1.0, n_estimators=300;, score=(train=-77.350, test=-322.311) total time= 3.7min
# [CV 4/5] END learning_rate=1.0, n_estimators=300;, score=(train=-118.606, test=-319.146) total time= 3.2min
# [CV 5/5] END learning_rate=1.0, n_estimators=300;, score=(train=-113.733, test=-312.336) total time= 3.3min
# [CV 1/5] END learning_rate=1.0, n_estimators=400;, score=(train=-128.802, test=-310.940) total time= 4.1min
# [CV 2/5] END learning_rate=1.0, n_estimators=400;, score=(train=-105.723, test=-313.879) total time= 6.0min
# [CV 3/5] END learning_rate=1.0, n_estimators=400;, score=(train=-87.756, test=-320.305) total time= 4.7min
# [CV 4/5] END learning_rate=1.0, n_estimators=400;, score=(train=-130.986, test=-318.815) total time= 4.1min
# [CV 5/5] END learning_rate=1.0, n_estimators=400;, score=(train=-127.096, test=-313.308) total time= 4.1min
# [CV 1/5] END learning_rate=1.0, n_estimators=500;, score=(train=-137.233, test=-310.980) total time= 5.0min
# [CV 2/5] END learning_rate=1.0, n_estimators=500;, score=(train=-113.221, test=-313.707) total time= 7.8min
# [CV 3/5] END learning_rate=1.0, n_estimators=500;, score=(train=-94.456, test=-320.023) total time= 5.7min
# [CV 4/5] END learning_rate=1.0, n_estimators=500;, score=(train=-139.234, test=-318.811) total time= 5.0min
# [CV 5/5] END learning_rate=1.0, n_estimators=500;, score=(train=-135.820, test=-313.368) total time= 5.0min
# GridSearchCV(estimator=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(random_state=42),
#                                          random_state=42),
#              param_grid={'learning_rate': [0.01, 0.1, 0.5, 1.0],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              return_train_score=True, scoring='neg_root_mean_squared_error',
#              verbose=4)

# %%
print("Best Score: %f" % grid.best_score_)
print("Best params: ", grid.best_params_)
# Out:
# Best Score: -314.858196
# Best params:  {'learning_rate': 0.5, 'n_estimators': 500}

# %%
pickle.dump(grid, open("grid_dt_v2_adaboost.sav", "wb"))

# %%
model = grid.best_estimator_

X_train, X_test, y_train, y_test = train_test_split(new_df, pd.Period(value = "2022Q3"))

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
model.score(X_test, y_test)
# Out:
# 0.9243438057005836

# %%
pickle.dump(model, open("model_dt_v2_adaboost.pkl", "wb"))

# %% [markdown]
# # Metrics

# %%
def produce_metrics(y_test, y_pred):
  mse = mean_squared_error(y_test, y_pred)
  mae = mean_absolute_error(y_test, y_pred)
  rtwo = r2_score(y_test, y_pred)
  mape = mean_absolute_percentage_error(y_test, y_pred)
  mdape = median_absolute_error(y_test, y_pred)/np.median(y_test)
  return mse, mse**(0.5), mae, rtwo, mape, mdape

# %%
mse, rmse, mae, rtwo, mape, mdape = produce_metrics(y_test, y_pred)
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"R2: {rtwo}")
print(f"MAPE: {mape}")
print(f"MdAPE: {mdape}")
# Out:
# MSE: 128269.75501304312
# RMSE: 358.14767207542076
# MAE: 272.7561002535079
# R2: 0.9243438057005836
# MAPE: 0.047809862122981245
# MdAPE: 0.04105464404018489

# %% [markdown]
# # Feature Importance

# %%
feature_impts = {}
for feature, importance in zip(model.feature_names_in_, model.feature_importances_):
    feature_impts[feature] = importance
feature_impts = dict(sorted(feature_impts.items(), key=lambda item: item[1], reverse=True)) # sort
print(feature_impts)
# Out:
# {'sale_month': 0.46349404134598376, 'cpi': 0.3142224897782665, 'floor': 0.17467020470370134, 'nearest_bus_stops': 0.0071195308004458405, 'floor_area': 0.005254943877066613, 'nearest_hawkers': 0.0037063224557495754, 'relative_tenure': 0.0033299373849364536, 'nearest_stores': 0.0029372953853747373, 'age': 0.002819395732149239, 'nearest_libraries': 0.002799502718838006, 'nearest_trains': 0.0019751354353035227, 'town_BISHAN': 0.0014033874315298887, 'avg_sora': 0.0013978036727297677, 'nearest_post_offices': 0.001373752387504427, 'town_WOODLANDS': 0.0013129405698998136, 'flat_type_4_ROOM': 0.0010891721052449896, 'flat_type_3_ROOM': 0.00101802630572954, 'town_OTHER': 0.0008832019188626687, 'nearest_parks': 0.0008699970915721354, 'town_JURONG_WEST': 0.0008331038605400338, 'nearest_pharmacies': 0.0008001340798026716, 'flat_model_OTHER': 0.0007935727946594827, 'nearest_atm': 0.0007607235268129027, 'nearest_primary_schools': 0.0006781524730587502, 'town_BUKIT_PANJANG': 0.00046536221331385034, 'town_YISHUN': 0.000453237610687274, 'town_BUKIT_MERAH': 0.00041273925517669295, 'town_TOA_PAYOH': 0.0003241550771729932, 'town_KALLANG/WHAMPOA': 0.0003036558112259243, 'town_SERANGOON': 0.0002807243405407344, 'town_CLEMENTI': 0.0002514680325870865, 'flat_type_EXECUTIVE': 0.00020841599219669686, 'town_TAMPINES': 0.00017437606315267315, 'flat_type_OTHER': 0.00016793368597556156, 'town_QUEENSTOWN': 0.00016737514300803802, 'flat_model_IMPROVED': 0.00012036080674224352, 'town_JURONG_EAST': 0.00011365441429434093, 'town_HOUGANG': 0.0001083421351685242, 'town_CHOA_CHU_KANG': 0.00010665787941608845, 'town_BEDOK': 0.00010169806711690691, 'town_ANG_MO_KIO': 8.545987712157532e-05, 'flat_model_MODEL_A': 8.364546082841486e-05, 'town_BUKIT_BATOK': 7.66322659117606e-05, 'flat_model_PREMIUM_APARTMENT': 7.500076194992502e-05, 'town_GEYLANG': 7.185228737031892e-05, 'flat_model_NEW_GENERATION': 5.583334157992876e-05, 'flat_type_5_ROOM': 5.213523474234052e-05, 'flat_model_STANDARD': 5.027724449787323e-05, 'flat_model_SIMPLIFIED': 3.119984917809228e-05, 'town_PASIR_RIS': 2.571420610426653e-05, 'town_SENGKANG': 2.4354893244720128e-05, 'town_SEMBAWANG': 1.8242404317532575e-05, 'flat_model_APARTMENT': 1.5966810961442336e-05, 'flat_model_MAISONETTE': 1.2203877690956023e-05, 'town_PUNGGOL': 8.653649730161483e-06, 'is_imputted_sora': 8.172162131250453e-06, 'flat_model_MODEL_A2': 1.7313091013942751e-06}

# %%
features_series = pd.Series(feature_impts.values(), index=feature_impts.keys())
features_series.sort_values(ascending=False,inplace=True)
plt.figure(figsize=(15,5))
features_series.plot(kind = 'bar')
plt.show()

# %% [markdown]
# # Actual vs Predicted

# %%
fig, ax = plt.subplots()
ax.axline((0, 0), slope=1, color="red")
plt.scatter(y_test, y_pred)
plt.title("Predicted vs Actual CPI-adjusted Per-square-metre Prices\n(Decision Tree with AdaBoost)")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
