# %%
import csv
import math
import random
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error, r2_score, make_scorer, mean_absolute_error, mean_absolute_percentage_error, median_absolute_error
from sklearn.ensemble import AdaBoostRegressor
import pickle
from copy import deepcopy

# %%
def process_df(df):
  new_df = deepcopy(df)
  new_df.drop(columns=["id", "sale_date", "address", "latitude_rad", "longitude_rad", "latitude", "longitude", "psm"], inplace=True)
  new_df = pd.get_dummies(new_df, columns=["flat_type", "flat_model", "town"], dummy_na = True, dtype=np.uint8)
  new_df.drop(columns=["town_nan", "flat_type_nan", "flat_model_nan"], inplace=True)
  return new_df

# %%
def train_test_split_sample(df, startMonth, endMonth):
    sample_df = df[df.sale_month.isin(list(range(startMonth, endMonth)))]
    sample_X, sample_y = sample_df.drop('cpi_psm', axis=1), sample_df.cpi_psm
    return sample_X, sample_y

# %%
def train_test_split_year(df, lookback_years):
    latest_month = df.sale_month.max()
    test_months = list(range(latest_month - lookback_years * 12, latest_month + 1))
    train_months = list(range(1, latest_month - lookback_years * 12))

    train = df[df.sale_month.isin(train_months)]
    test = df[df.sale_month.isin(test_months)]
  
    X_train, y_train = train[train.columns.difference(["cpi_psm"])], train["cpi_psm"]
    X_test, y_test = test[test.columns.difference(["cpi_psm"])], test["cpi_psm"]
    
    return X_train, X_test, y_train, y_test

# %%
PROCESSED_DATA_PATH = os.path.join("../", "../", "data_processed", "resale_flat_prices")
SEED = 42

# %%
df = pd.read_csv(os.path.join(PROCESSED_DATA_PATH, "engineered_data.csv"))
df.head(10)
# Out:
#    id         town flat_type flat_model   sale_date  floor  age  \
# 0   1  JURONG_WEST    3_ROOM   IMPROVED  1990-01-01    5.0   16
# 1   2        OTHER    5_ROOM   STANDARD  1990-01-01    5.0   15
# 2   3  BUKIT_MERAH    3_ROOM   IMPROVED  1990-01-01    5.0   15
# 3   4  BUKIT_MERAH     OTHER   IMPROVED  1990-01-01    8.0   21
# 4   5  BUKIT_MERAH     OTHER   IMPROVED  1990-01-01   11.0   21
# 5   6  BUKIT_MERAH     OTHER   IMPROVED  1990-01-01    8.0   21
# 6   7  BUKIT_MERAH    3_ROOM   IMPROVED  1990-01-01    8.0    7
# 7   8  BUKIT_MERAH    3_ROOM    MODEL_A  1990-01-01    8.0    6
# 8   9  BUKIT_MERAH    3_ROOM    MODEL_A  1990-01-01    5.0    6
# 9  10  BUKIT_MERAH    3_ROOM   IMPROVED  1990-01-01    2.0   15
#
#    relative_tenure  floor_area          psm  ... nearest_post_offices  \
# 0         0.899953        70.0   334.285714  ...             0.798752
# 1         0.902280       120.0   916.666667  ...             3.042559
# 2         0.902280        63.0   722.222222  ...             1.148847
# 3         0.887322        29.0   251.724138  ...             1.294327
# 4         0.887322        29.0   251.724138  ...             1.294327
# 5         0.887322        29.0   310.344828  ...             1.294327
# 6         0.918820        64.0   687.500000  ...             1.018641
# 7         0.920652        74.0  1128.378378  ...             1.089870
# 8         0.920652        73.0  1150.684932  ...             1.657478
# 9         0.902280        76.0   671.052632  ...             0.690789
#
#    nearest_bus_stops  nearest_pharmacies  nearest_primary_schools  \
# 0           0.195397            0.761661                 0.541789
# 1           0.090376            1.133326                 0.159056
# 2           0.446105            0.850333                 0.943485
# 3           1.620819            0.431442                 0.691163
# 4           1.620819            0.431442                 0.691163
# 5           1.620819            0.431442                 0.691163
# 6           0.485058            0.986821                 0.800866
# 7           0.544915            0.567711                 0.490547
# 8           0.053197            0.982875                 0.340834
# 9           0.083148            0.637859                 0.507003
#
#    nearest_parks  nearest_trains  sale_month   cpi      cpi_psm  avg_sora
# 0       0.947906        0.904104           1  61.9   595.125779       NaN
# 1       0.330270        1.954674           1  61.9  1631.933226       NaN
# 2       0.737703        0.932695           1  61.9  1285.765572       NaN
# 3       0.311404        0.448964           1  61.9   448.142165       NaN
# 4       0.311404        0.448964           1  61.9   448.142165       NaN
# 5       0.311404        0.448964           1  61.9   552.504039       NaN
# 6       0.808590        0.940111           1  61.9  1223.949919       NaN
# 7       0.708861        0.799126           1  61.9  2008.841636       NaN
# 8       1.013329        0.940071           1  61.9  2048.553788       NaN
# 9       0.406147        1.175060           1  61.9  1194.668821       NaN
#
# [10 rows x 29 columns]

# %%
df["is_imputted_sora"] = np.where(df["avg_sora"].isnull(), True, False)

imp = SimpleImputer()
df["avg_sora"] = imp.fit_transform(df["avg_sora"].to_numpy().reshape(-1, 1))

# %%
df.describe()
# Out:
#                   id          floor            age  relative_tenure  \
# count  865827.000000  865827.000000  865827.000000    865827.000000
# mean   432914.000000       7.626058      17.349350         0.892896
# std    249942.870098       4.738340      10.217708         0.029046
# min         1.000000       2.000000       0.000000         0.731586
# 25%    216457.500000       5.000000       9.000000         0.878870
# 50%    432914.000000       8.000000      16.000000         0.899953
# 75%    649370.500000      11.000000      24.000000         0.915007
# max    865827.000000      50.000000      55.000000         0.930702
#
#           floor_area            psm       latitude      longitude  \
# count  865827.000000  865827.000000  865827.000000  865827.000000
# mean       96.135123    3173.083607       1.497366     103.148474
# std        25.796313    1385.776553       2.612377      11.573640
# min        28.000000     161.290323     -37.840251    -122.683299
# 25%        73.000000    2266.666667       1.335322     103.772049
# 50%        93.000000    2870.370370       1.355961     103.843296
# 75%       114.000000    3990.180006       1.383056     103.897860
# max       307.000000   13310.344828      50.820779     145.019498
#
#         latitude_rad  longitude_rad  ...  nearest_post_offices  \
# count  865827.000000  865827.000000  ...         865827.000000
# mean        0.026134       1.800280  ...             62.788172
# std         0.045595       0.201998  ...            923.588875
# min        -0.660437      -2.141228  ...              0.007724
# 25%         0.023306       1.811164  ...              0.754831
# 50%         0.023666       1.812407  ...              1.136412
# 75%         0.024139       1.813360  ...              1.559133
# max         0.886990       2.531068  ...          16929.865540
#
#        nearest_bus_stops  nearest_pharmacies  nearest_primary_schools  \
# count      865827.000000       865827.000000            865827.000000
# mean           61.708270           62.231490                61.990540
# std           923.284911          923.497181               923.502716
# min             0.000003            0.000790                 0.042886
# 25%             0.076599            0.395358                 0.241143
# 50%             0.112533            0.610644                 0.370503
# 75%             0.156376            0.869802                 0.540301
# max         16924.138572        16928.066230             16927.190593
#
#        nearest_parks  nearest_trains     sale_month            cpi  \
# count  865827.000000   865827.000000  865827.000000  865827.000000
# mean       62.338973       62.217020     190.483063      82.131055
# std       923.385468      923.496916     104.298678      11.879488
# min         0.021691        0.018401       1.000000      61.900000
# 25%         0.477918        0.375599     107.000000      73.400000
# 50%         0.705703        0.585058     175.000000      76.500000
# 75%         0.994037        0.853369     269.000000      95.900000
# max     16926.344996    16927.966733     393.000000     110.200000
#
#              cpi_psm       avg_sora
# count  865827.000000  865827.000000
# mean     4131.625468       0.763427
# std      1363.166128       0.659903
# min       284.387097       0.035633
# 25%      3321.083800       0.260618
# 50%      4031.953168       0.763427
# 75%      4868.754343       0.763427
# max     14163.126574       3.414986
#
# [8 rows x 24 columns]

# %%
new_df = process_df(df)
sample_X, sample_y = train_test_split_sample(new_df, 200, 236)

# %%
model = AdaBoostRegressor(
    base_estimator=DecisionTreeRegressor(random_state=SEED, max_depth=3), 
    random_state=SEED
)

# %% [markdown]
# # GridSearchCV

# %%
parameters = {'n_estimators':[100,200,300,400,500],'learning_rate':[0.01,0.1,0.5,1.0]}
grid = GridSearchCV(model, parameters, scoring='neg_root_mean_squared_error', verbose = 4, return_train_score = True)
grid.fit(X=sample_X, y=sample_y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END learning_rate=0.01, n_estimators=100;, score=(train=-695.155, test=-581.527) total time=  37.9s
# [CV 2/5] END learning_rate=0.01, n_estimators=100;, score=(train=-685.272, test=-642.007) total time=  32.6s
# [CV 3/5] END learning_rate=0.01, n_estimators=100;, score=(train=-645.930, test=-804.299) total time=  37.5s
# [CV 4/5] END learning_rate=0.01, n_estimators=100;, score=(train=-663.342, test=-723.963) total time=  39.7s
# [CV 5/5] END learning_rate=0.01, n_estimators=100;, score=(train=-672.365, test=-708.455) total time=  42.2s
# [CV 1/5] END learning_rate=0.01, n_estimators=200;, score=(train=-684.661, test=-591.808) total time= 1.2min
# [CV 2/5] END learning_rate=0.01, n_estimators=200;, score=(train=-677.983, test=-630.778) total time= 1.2min
# [CV 3/5] END learning_rate=0.01, n_estimators=200;, score=(train=-642.518, test=-797.848) total time=  60.0s
# [CV 4/5] END learning_rate=0.01, n_estimators=200;, score=(train=-655.302, test=-720.818) total time= 1.1min
# [CV 5/5] END learning_rate=0.01, n_estimators=200;, score=(train=-662.386, test=-701.881) total time= 1.1min
# [CV 1/5] END learning_rate=0.01, n_estimators=300;, score=(train=-672.523, test=-603.671) total time= 1.6min
# [CV 2/5] END learning_rate=0.01, n_estimators=300;, score=(train=-669.428, test=-620.254) total time= 1.7min
# [CV 3/5] END learning_rate=0.01, n_estimators=300;, score=(train=-634.921, test=-782.314) total time= 1.6min
# [CV 4/5] END learning_rate=0.01, n_estimators=300;, score=(train=-647.287, test=-714.059) total time= 1.8min
# [CV 5/5] END learning_rate=0.01, n_estimators=300;, score=(train=-647.204, test=-691.791) total time= 1.9min
# [CV 1/5] END learning_rate=0.01, n_estimators=400;, score=(train=-667.807, test=-617.173) total time= 2.3min
# [CV 2/5] END learning_rate=0.01, n_estimators=400;, score=(train=-657.461, test=-615.843) total time= 2.2min
# [CV 3/5] END learning_rate=0.01, n_estimators=400;, score=(train=-628.090, test=-773.287) total time= 2.3min
# [CV 4/5] END learning_rate=0.01, n_estimators=400;, score=(train=-639.460, test=-704.881) total time= 2.3min
# [CV 5/5] END learning_rate=0.01, n_estimators=400;, score=(train=-639.650, test=-684.468) total time= 2.1min
# [CV 1/5] END learning_rate=0.01, n_estimators=500;, score=(train=-665.850, test=-633.718) total time= 3.5min
# [CV 2/5] END learning_rate=0.01, n_estimators=500;, score=(train=-650.995, test=-643.959) total time= 3.9min
# [CV 3/5] END learning_rate=0.01, n_estimators=500;, score=(train=-621.338, test=-764.281) total time= 2.8min
# [CV 4/5] END learning_rate=0.01, n_estimators=500;, score=(train=-634.737, test=-697.136) total time= 3.0min
# [CV 5/5] END learning_rate=0.01, n_estimators=500;, score=(train=-638.184, test=-680.476) total time= 3.1min
# [CV 1/5] END learning_rate=0.1, n_estimators=100;, score=(train=-655.353, test=-670.666) total time=  36.3s
# [CV 2/5] END learning_rate=0.1, n_estimators=100;, score=(train=-644.299, test=-680.194) total time=  37.7s
# [CV 3/5] END learning_rate=0.1, n_estimators=100;, score=(train=-609.536, test=-756.977) total time=  36.9s
# [CV 4/5] END learning_rate=0.1, n_estimators=100;, score=(train=-623.797, test=-671.536) total time=  38.5s
# [CV 5/5] END learning_rate=0.1, n_estimators=100;, score=(train=-630.806, test=-656.141) total time=  32.7s
# [CV 1/5] END learning_rate=0.1, n_estimators=200;, score=(train=-653.977, test=-691.873) total time= 1.1min
# [CV 2/5] END learning_rate=0.1, n_estimators=200;, score=(train=-643.238, test=-711.545) total time= 1.1min
# [CV 3/5] END learning_rate=0.1, n_estimators=200;, score=(train=-610.487, test=-758.203) total time=  59.4s
# [CV 4/5] END learning_rate=0.1, n_estimators=200;, score=(train=-625.776, test=-649.003) total time=  59.7s
# [CV 5/5] END learning_rate=0.1, n_estimators=200;, score=(train=-648.091, test=-616.388) total time= 1.2min
# [CV 1/5] END learning_rate=0.1, n_estimators=300;, score=(train=-665.505, test=-740.084) total time= 1.4min
# [CV 2/5] END learning_rate=0.1, n_estimators=300;, score=(train=-647.282, test=-728.628) total time= 1.6min
# [CV 3/5] END learning_rate=0.1, n_estimators=300;, score=(train=-635.980, test=-759.565) total time= 1.5min
# [CV 4/5] END learning_rate=0.1, n_estimators=300;, score=(train=-643.873, test=-645.293) total time= 1.5min
# [CV 5/5] END learning_rate=0.1, n_estimators=300;, score=(train=-655.133, test=-605.190) total time= 1.6min
# [CV 1/5] END learning_rate=0.1, n_estimators=400;, score=(train=-674.866, test=-770.647) total time= 1.9min
# [CV 2/5] END learning_rate=0.1, n_estimators=400;, score=(train=-652.546, test=-743.967) total time= 2.0min
# [CV 3/5] END learning_rate=0.1, n_estimators=400;, score=(train=-648.139, test=-753.935) total time= 2.4min
# [CV 4/5] END learning_rate=0.1, n_estimators=400;, score=(train=-651.741, test=-643.558) total time= 2.7min
# [CV 5/5] END learning_rate=0.1, n_estimators=400;, score=(train=-659.691, test=-598.109) total time= 2.6min
# [CV 1/5] END learning_rate=0.1, n_estimators=500;, score=(train=-679.736, test=-786.826) total time= 2.4min
# [CV 2/5] END learning_rate=0.1, n_estimators=500;, score=(train=-656.628, test=-753.099) total time= 2.5min
# [CV 3/5] END learning_rate=0.1, n_estimators=500;, score=(train=-654.361, test=-750.609) total time= 2.3min
# [CV 4/5] END learning_rate=0.1, n_estimators=500;, score=(train=-657.527, test=-642.726) total time= 2.3min
# [CV 5/5] END learning_rate=0.1, n_estimators=500;, score=(train=-662.283, test=-595.783) total time= 2.4min
# [CV 1/5] END learning_rate=0.5, n_estimators=100;, score=(train=-662.808, test=-774.109) total time=  26.5s
# [CV 2/5] END learning_rate=0.5, n_estimators=100;, score=(train=-649.948, test=-747.785) total time=  26.8s
# [CV 3/5] END learning_rate=0.5, n_estimators=100;, score=(train=-642.760, test=-732.650) total time=  28.9s
# [CV 4/5] END learning_rate=0.5, n_estimators=100;, score=(train=-643.640, test=-639.434) total time=  27.1s
# [CV 5/5] END learning_rate=0.5, n_estimators=100;, score=(train=-641.776, test=-589.183) total time=  31.6s
# [CV 1/5] END learning_rate=0.5, n_estimators=200;, score=(train=-651.548, test=-757.838) total time=  58.1s
# [CV 2/5] END learning_rate=0.5, n_estimators=200;, score=(train=-647.053, test=-742.701) total time=  58.9s
# [CV 3/5] END learning_rate=0.5, n_estimators=200;, score=(train=-636.494, test=-717.492) total time=  48.2s
# [CV 4/5] END learning_rate=0.5, n_estimators=200;, score=(train=-639.792, test=-625.881) total time=  51.6s
# [CV 5/5] END learning_rate=0.5, n_estimators=200;, score=(train=-638.116, test=-579.126) total time=  50.7s
# [CV 1/5] END learning_rate=0.5, n_estimators=300;, score=(train=-648.124, test=-747.011) total time= 1.2min
# [CV 2/5] END learning_rate=0.5, n_estimators=300;, score=(train=-631.403, test=-718.733) total time= 1.3min
# [CV 3/5] END learning_rate=0.5, n_estimators=300;, score=(train=-631.515, test=-709.997) total time= 1.2min
# [CV 4/5] END learning_rate=0.5, n_estimators=300;, score=(train=-639.371, test=-620.394) total time= 1.2min
# [CV 5/5] END learning_rate=0.5, n_estimators=300;, score=(train=-633.235, test=-577.281) total time= 1.1min
# [CV 1/5] END learning_rate=0.5, n_estimators=400;, score=(train=-654.551, test=-758.913) total time= 1.5min
# [CV 2/5] END learning_rate=0.5, n_estimators=400;, score=(train=-629.662, test=-720.931) total time= 1.5min
# [CV 3/5] END learning_rate=0.5, n_estimators=400;, score=(train=-632.078, test=-712.498) total time= 1.5min
# [CV 4/5] END learning_rate=0.5, n_estimators=400;, score=(train=-639.541, test=-617.624) total time= 1.5min
# [CV 5/5] END learning_rate=0.5, n_estimators=400;, score=(train=-638.610, test=-575.830) total time= 1.6min
# [CV 1/5] END learning_rate=0.5, n_estimators=500;, score=(train=-649.659, test=-752.500) total time= 1.9min
# [CV 2/5] END learning_rate=0.5, n_estimators=500;, score=(train=-630.170, test=-727.337) total time= 1.8min
# [CV 3/5] END learning_rate=0.5, n_estimators=500;, score=(train=-621.414, test=-705.131) total time= 2.5min
# [CV 4/5] END learning_rate=0.5, n_estimators=500;, score=(train=-642.519, test=-619.344) total time= 1.9min
# [CV 5/5] END learning_rate=0.5, n_estimators=500;, score=(train=-637.148, test=-576.924) total time= 1.9min
# [CV 1/5] END learning_rate=1.0, n_estimators=100;, score=(train=-640.960, test=-737.487) total time=  26.8s
# [CV 2/5] END learning_rate=1.0, n_estimators=100;, score=(train=-631.187, test=-710.469) total time=  25.1s
# [CV 3/5] END learning_rate=1.0, n_estimators=100;, score=(train=-604.515, test=-710.964) total time=  24.2s
# [CV 4/5] END learning_rate=1.0, n_estimators=100;, score=(train=-625.456, test=-612.276) total time=  23.4s
# [CV 5/5] END learning_rate=1.0, n_estimators=100;, score=(train=-621.362, test=-574.150) total time=  23.3s
# [CV 1/5] END learning_rate=1.0, n_estimators=200;, score=(train=-641.559, test=-752.666) total time=  42.5s
# [CV 2/5] END learning_rate=1.0, n_estimators=200;, score=(train=-619.464, test=-700.227) total time=  44.5s
# [CV 3/5] END learning_rate=1.0, n_estimators=200;, score=(train=-606.643, test=-695.104) total time=  44.6s
# [CV 4/5] END learning_rate=1.0, n_estimators=200;, score=(train=-622.836, test=-604.690) total time=  43.3s
# [CV 5/5] END learning_rate=1.0, n_estimators=200;, score=(train=-615.384, test=-575.236) total time=  45.0s
# [CV 1/5] END learning_rate=1.0, n_estimators=300;, score=(train=-639.652, test=-741.767) total time= 1.1min
# [CV 2/5] END learning_rate=1.0, n_estimators=300;, score=(train=-621.953, test=-711.547) total time= 1.1min
# [CV 3/5] END learning_rate=1.0, n_estimators=300;, score=(train=-614.107, test=-690.833) total time= 1.3min
# [CV 4/5] END learning_rate=1.0, n_estimators=300;, score=(train=-629.822, test=-604.809) total time= 1.1min
# [CV 5/5] END learning_rate=1.0, n_estimators=300;, score=(train=-617.750, test=-569.493) total time= 1.2min
# [CV 1/5] END learning_rate=1.0, n_estimators=400;, score=(train=-639.652, test=-741.767) total time= 1.1min
# [CV 2/5] END learning_rate=1.0, n_estimators=400;, score=(train=-619.841, test=-706.245) total time= 1.6min
# [CV 3/5] END learning_rate=1.0, n_estimators=400;, score=(train=-616.281, test=-688.265) total time= 1.4min
# [CV 4/5] END learning_rate=1.0, n_estimators=400;, score=(train=-635.542, test=-611.938) total time= 1.9min
# [CV 5/5] END learning_rate=1.0, n_estimators=400;, score=(train=-617.822, test=-564.401) total time= 1.5min
# [CV 1/5] END learning_rate=1.0, n_estimators=500;, score=(train=-639.652, test=-741.767) total time= 1.2min
# [CV 2/5] END learning_rate=1.0, n_estimators=500;, score=(train=-616.667, test=-704.570) total time= 1.8min
# [CV 3/5] END learning_rate=1.0, n_estimators=500;, score=(train=-615.342, test=-685.963) total time= 1.9min
# [CV 4/5] END learning_rate=1.0, n_estimators=500;, score=(train=-637.352, test=-610.450) total time= 1.8min
# [CV 5/5] END learning_rate=1.0, n_estimators=500;, score=(train=-613.584, test=-563.704) total time= 1.7min
# GridSearchCV(estimator=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=3,
#                                                                               random_state=42),
#                                          random_state=42),
#              param_grid={'learning_rate': [0.01, 0.1, 0.5, 1.0],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              return_train_score=True, scoring='neg_root_mean_squared_error',
#              verbose=4)

# %%
print("Best Score: %f" % grid.best_score_)
print("Best params: ", grid.best_params_)
# Out:
# Best Score: -661.290797
# Best params:  {'learning_rate': 1.0, 'n_estimators': 500}

# %%
pickle.dump(grid, open("grid_dt_v2_adaboost.sav", "wb"))

# %%
model = grid.best_estimator_

X_train, X_test, y_train, y_test = train_test_split_year(new_df, 4)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
model.score(X_test, y_test)
# Out:
# 0.39940362557872533

# %%
pickle.dump(model, open("model_dt_v2_adaboost.pkl", "wb"))

# %% [markdown]
# # Metrics

# %%
def produce_metrics(y_test, y_pred):
  mse = mean_squared_error(y_test, y_pred)
  mae = mean_absolute_error(y_test, y_pred)
  rtwo = r2_score(y_test, y_pred)
  mape = mean_absolute_percentage_error(y_test, y_pred)
  mdape = median_absolute_error(y_test, y_pred)/np.median(y_test)
  return mse, mse**(0.5), mae, rtwo, mape, mdape

# %%
mse, rmse, mae, rtwo, mape, mdape = produce_metrics(y_test, y_pred)
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"R2: {rtwo}")
print(f"MAPE: {mape}")
print(f"MdAPE: {mdape}")
# Out:
# MSE: 1197958.106222228
# RMSE: 1094.5127254729512
# MAE: 903.7533006487455
# R2: 0.39940362557872533
# MAPE: 0.1842378427186966
# MdAPE: 0.16254358464418317

# %% [markdown]
# # Feature Importance

# %%
feature_impts = {}
for feature, importance in zip(model.feature_names_in_, model.feature_importances_):
    feature_impts[feature] = importance
feature_impts = dict(sorted(feature_impts.items(), key=lambda item: item[1], reverse=True)) # sort
print(feature_impts)
# Out:
# {'sale_month': 0.2727650583375286, 'cpi': 0.10350940581281957, 'floor_area': 0.08862465663200648, 'nearest_bus_stops': 0.055115361405041495, 'floor': 0.05156763079588865, 'flat_model_OTHER': 0.05048513048008001, 'age': 0.04496359745415328, 'town_KALLANG/WHAMPOA': 0.04036892971023934, 'nearest_hawkers': 0.03376250217779529, 'nearest_pharmacies': 0.030578713912768042, 'relative_tenure': 0.02640209965859206, 'nearest_libraries': 0.024621784501157245, 'avg_sora': 0.023912860782419977, 'nearest_primary_schools': 0.02133847150546655, 'nearest_post_offices': 0.01771512294180555, 'nearest_stores': 0.017106856507251005, 'nearest_atm': 0.01503854688029669, 'town_BUKIT_MERAH': 0.014695374415941237, 'nearest_trains': 0.011645101057293892, 'flat_model_IMPROVED': 0.010941587941699124, 'nearest_parks': 0.008177515348206052, 'town_OTHER': 0.008106298054747081, 'flat_type_3_ROOM': 0.005164533872258772, 'town_WOODLANDS': 0.004969826849264645, 'flat_type_4_ROOM': 0.004039188724007851, 'town_JURONG_WEST': 0.0032155440785268637, 'flat_model_NEW_GENERATION': 0.002834641594673258, 'flat_type_EXECUTIVE': 0.002290031285605164, 'town_QUEENSTOWN': 0.0019983879055397035, 'town_BEDOK': 0.0012809379899599378, 'town_SENGKANG': 0.0011031171987291072, 'town_GEYLANG': 0.0005068498453412153, 'flat_model_STANDARD': 0.0002494207177752736, 'flat_model_PREMIUM_APARTMENT': 0.00024618198470138867, 'town_BISHAN': 0.0002052707550970021, 'town_CLEMENTI': 0.0001587364327360409, 'town_TOA_PAYOH': 0.00012483276882842122, 'flat_type_5_ROOM': 0.00011417671786123038, 'town_YISHUN': 5.387636302727921e-05, 'flat_model_SIMPLIFIED': 1.8386028697254428e-06, 'flat_model_APARTMENT': 0.0, 'flat_model_MAISONETTE': 0.0, 'flat_model_MODEL_A': 0.0, 'flat_model_MODEL_A2': 0.0, 'flat_type_OTHER': 0.0, 'is_imputted_sora': 0.0, 'town_ANG_MO_KIO': 0.0, 'town_BUKIT_BATOK': 0.0, 'town_BUKIT_PANJANG': 0.0, 'town_CHOA_CHU_KANG': 0.0, 'town_HOUGANG': 0.0, 'town_JURONG_EAST': 0.0, 'town_PASIR_RIS': 0.0, 'town_PUNGGOL': 0.0, 'town_SEMBAWANG': 0.0, 'town_SERANGOON': 0.0, 'town_TAMPINES': 0.0}

# %%
features_series = pd.Series(feature_impts.values(), index=feature_impts.keys())
features_series.sort_values(ascending=False,inplace=True)
plt.figure(figsize=(15,5))
features_series.plot(kind = 'bar')
plt.show()

# %% [markdown]
# # Actual vs Predicted

# %%
fig, ax = plt.subplots()
ax.axline((0, 0), slope=1, color="red")
plt.scatter(y_test, y_pred)
plt.title("Predicted vs Actual CPI-adjusted Per-square-metre Prices\n(Decision Tree with AdaBoost)")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
